# %% [markdown]
# <a href="https://colab.research.google.com/github/REVOLUTTION/Challenge-Alura-Store/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
# prompt: Con DataFrame tienda: tienda1

# Display the first few rows of the 'tienda' DataFrame.
tienda.head()

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)


tienda["Precio"]
suma_total = sum(tienda["Precio"])
print(f"Suma total: {suma_total:,.0f}")
# Out:
# Suma total: 1,150,880,400

# %%
tienda2["Precio"]
suma_total = sum(tienda2["Precio"])
suma_envio2 = sum(tienda2["Costo de envío"])
print(f"Suma total: {suma_total:,.0f}")
print(f"Suma envío total: {suma_envio2:,.0f}")
# Out:
# Suma total: 1,116,343,500
# Suma envío total: 59,485,100

# %%
tienda3["Precio"]
suma_total = sum(tienda3["Precio"])
suma_envio3 = sum(tienda3["Costo de envío"])
print(f"Suma total: {suma_total:,.0f}")
print(f"Suma envío total: {suma_envio3:,.0f}")
# Out:
# Suma total: 1,098,019,600
# Suma envío total: 58,516,600

# %%
tienda4["Precio"]
suma_total = sum(tienda4["Precio"])
suma_envio4 = sum(tienda4["Costo de envío"])
print(f"Suma total: {suma_total:,.0f}")
print(f"Suma envío total: {suma_envio4:,.0f}")
# Out:
# Suma total: 1,038,375,700
# Suma envío total: 55,317,400

# %% [markdown]
# vamos a graficar las ventas por tienda

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calculamos los valores
suma_tienda = sum(tienda["Precio"])
suma_tienda2 = sum(tienda2["Precio"])
suma_tienda3 = sum(tienda3["Precio"])
suma_tienda4 = sum(tienda4["Precio"])


# Imprimimos los valores
print(f"Suma total tienda: {suma_tienda:,.0f}")

print(f"Suma total tienda2: {suma_tienda2:,.0f}")

print(f"Suma total tienda3: {suma_tienda3:,.0f}")
print(f"Suma total tienda4: {suma_tienda4:,.0f}")

# Creamos el gráfico de barras
tiendas = ['Tienda', 'Tienda2','Tienda3','Tienda4']
valores_tiendas = [suma_tienda, suma_tienda2,suma_tienda3, suma_tienda4]

bar_width = 0.35
index = np.arange(len(tiendas))

plt.figure(figsize=(10, 6))

# Crear barras para precios
bars1 = plt.bar(index, valores_tiendas, bar_width, label='Precios', color='royalblue')



# Personalización del gráfico
plt.title('Comparación de Precios y Envíos por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Valores')
plt.xticks(index + bar_width/2, tiendas)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Añadir etiquetas con los valores
for bars in [bars1]:
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:,.0f}',
                ha='center', va='bottom')

plt.tight_layout()

# Añadimos formato a los ejes y título
plt.title('Ventas totales por tienda')
plt.ylabel('Suma total')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Mostramos los valores en las barras
for i, valor in enumerate(valores_tiendas):
    plt.text(i, valor, f"{valor:,.0f}", ha='center', va='bottom')

plt.show()
# Out:
# Suma total tienda: 1,150,880,400
# Suma total tienda2: 1,116,343,500
# Suma total tienda3: 1,098,019,600
# Suma total tienda4: 1,038,375,700

# %% [markdown]
# # 2. Ventas por categoría

# %%
import pandas as pd

# 1. Configurar pandas para alineación automática (válido en Colab)
pd.set_option('display.colheader_justify', 'left')  # Encabezados alineados a la izquierda
pd.set_option('display.float_format', '{:,.0f}'.format)  # Formato numérico sin decimales

# 2. Agrupar por categoría y contar productos
ventas_por_categoria = tienda.groupby('Categoría del Producto', as_index=False).size()
ventas_por_categoria.columns = ['Categoría del Producto', 'Unidades Vendidas']  # Renombrar columnas

# Agregar columna "Tienda"
ventas_por_categoria.insert(0, 'Tienda', 'Tienda')  # Añade columna al inicio

# 3. Mostrar el DataFrame con alineación automática
ventas_por_categoria.style \
    .set_properties(**{'text-align': 'left'}, subset=['Categoría del Producto']) \
    .set_properties(**{'text-align': 'right'}, subset=['Unidades Vendidas']) \
    .format({'Unidades Vendidas': '{:,.0f}'})
# Out:
# <style type="text/css">
# #T_eee3f_row0_col1, #T_eee3f_row1_col1, #T_eee3f_row2_col1, #T_eee3f_row3_col1, #T_eee3f_row4_col1, #T_eee3f_row5_col1, #T_eee3f_row6_col1, #T_eee3f_row7_col1 {
#   text-align: left;
# }
# #T_eee3f_row0_col2, #T_eee3f_row1_col2, #T_eee3f_row2_col2, #T_eee3f_row3_col2, #T_eee3f_row4_col2, #T_eee3f_row5_col2, #T_eee3f_row6_col2, #T_eee3f_row7_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_eee3f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eee3f_level0_col0" class="col_heading level0 col0" >Tienda</th>
#       <th id="T_eee3f_level0_col1" class="col_heading level0 col1" >Categoría del Producto</th>
#       <th id="T_eee3f_level0_col2" class="col_heading level0 col2" >Unidades Vendidas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eee3f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eee3f_row0_col0" class="data row0 col0" >Tienda</td>
# ...

# %%
import pandas as pd

# 1. Configurar pandas para alineación automática (válido en Colab)
pd.set_option('display.colheader_justify', 'left')  # Encabezados alineados a la izquierda
pd.set_option('display.float_format', '{:,.0f}'.format)  # Formato numérico sin decimales

# 2. Agrupar por categoría y contar productos
ventas_por_categoria = tienda2.groupby('Categoría del Producto', as_index=False).size()
ventas_por_categoria.columns = ['Categoría del Producto', 'Unidades Vendidas']  # Renombrar columnas

# Agregar columna "Tienda"
ventas_por_categoria.insert(0, 'Tienda', 'Tienda2')  # Añade columna al inicio

# 3. Mostrar el DataFrame con alineación automática
ventas_por_categoria.style \
    .set_properties(**{'text-align': 'left'}, subset=['Categoría del Producto']) \
    .set_properties(**{'text-align': 'right'}, subset=['Unidades Vendidas']) \
    .format({'Unidades Vendidas': '{:,.0f}'})
# Out:
# <style type="text/css">
# #T_87c62_row0_col1, #T_87c62_row1_col1, #T_87c62_row2_col1, #T_87c62_row3_col1, #T_87c62_row4_col1, #T_87c62_row5_col1, #T_87c62_row6_col1, #T_87c62_row7_col1 {
#   text-align: left;
# }
# #T_87c62_row0_col2, #T_87c62_row1_col2, #T_87c62_row2_col2, #T_87c62_row3_col2, #T_87c62_row4_col2, #T_87c62_row5_col2, #T_87c62_row6_col2, #T_87c62_row7_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_87c62" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87c62_level0_col0" class="col_heading level0 col0" >Tienda</th>
#       <th id="T_87c62_level0_col1" class="col_heading level0 col1" >Categoría del Producto</th>
#       <th id="T_87c62_level0_col2" class="col_heading level0 col2" >Unidades Vendidas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87c62_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87c62_row0_col0" class="data row0 col0" >Tienda2</td>
# ...

# %%
import pandas as pd

# 1. Configurar pandas para alineación automática (válido en Colab)
pd.set_option('display.colheader_justify', 'left')  # Encabezados alineados a la izquierda
pd.set_option('display.float_format', '{:,.0f}'.format)  # Formato numérico sin decimales

# 2. Agrupar por categoría y contar productos
ventas_por_categoria = tienda3.groupby('Categoría del Producto', as_index=False).size()
ventas_por_categoria.columns = ['Categoría del Producto', 'Unidades Vendidas']  # Renombrar columnas

# Agregar columna "Tienda"
ventas_por_categoria.insert(0, 'Tienda', 'Tienda3')  # Añade columna al inicio

# 3. Mostrar el DataFrame con alineación automática
ventas_por_categoria.style \
    .set_properties(**{'text-align': 'left'}, subset=['Categoría del Producto']) \
    .set_properties(**{'text-align': 'right'}, subset=['Unidades Vendidas']) \
    .format({'Unidades Vendidas': '{:,.0f}'})
# Out:
# <style type="text/css">
# #T_83292_row0_col1, #T_83292_row1_col1, #T_83292_row2_col1, #T_83292_row3_col1, #T_83292_row4_col1, #T_83292_row5_col1, #T_83292_row6_col1, #T_83292_row7_col1 {
#   text-align: left;
# }
# #T_83292_row0_col2, #T_83292_row1_col2, #T_83292_row2_col2, #T_83292_row3_col2, #T_83292_row4_col2, #T_83292_row5_col2, #T_83292_row6_col2, #T_83292_row7_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_83292" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83292_level0_col0" class="col_heading level0 col0" >Tienda</th>
#       <th id="T_83292_level0_col1" class="col_heading level0 col1" >Categoría del Producto</th>
#       <th id="T_83292_level0_col2" class="col_heading level0 col2" >Unidades Vendidas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83292_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83292_row0_col0" class="data row0 col0" >Tienda3</td>
# ...

# %%
import pandas as pd

# 1. Configurar pandas para alineación automática (válido en Colab)
pd.set_option('display.colheader_justify', 'left')  # Encabezados alineados a la izquierda
pd.set_option('display.float_format', '{:,.0f}'.format)  # Formato numérico sin decimales

# 2. Agrupar por categoría y contar productos
ventas_por_categoria = tienda4.groupby('Categoría del Producto', as_index=False).size()
ventas_por_categoria.columns = ['Categoría del Producto', 'Unidades Vendidas']  # Renombrar columnas

# Agregar columna "Tienda"
ventas_por_categoria.insert(0, 'Tienda', 'Tienda4')  # Añade columna al inicio

# 3. Mostrar el DataFrame con alineación automática
ventas_por_categoria.style \
    .set_properties(**{'text-align': 'left'}, subset=['Categoría del Producto']) \
    .set_properties(**{'text-align': 'right'}, subset=['Unidades Vendidas']) \
    .format({'Unidades Vendidas': '{:,.0f}'})
# Out:
# <style type="text/css">
# #T_fcce8_row0_col1, #T_fcce8_row1_col1, #T_fcce8_row2_col1, #T_fcce8_row3_col1, #T_fcce8_row4_col1, #T_fcce8_row5_col1, #T_fcce8_row6_col1, #T_fcce8_row7_col1 {
#   text-align: left;
# }
# #T_fcce8_row0_col2, #T_fcce8_row1_col2, #T_fcce8_row2_col2, #T_fcce8_row3_col2, #T_fcce8_row4_col2, #T_fcce8_row5_col2, #T_fcce8_row6_col2, #T_fcce8_row7_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_fcce8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcce8_level0_col0" class="col_heading level0 col0" >Tienda</th>
#       <th id="T_fcce8_level0_col1" class="col_heading level0 col1" >Categoría del Producto</th>
#       <th id="T_fcce8_level0_col2" class="col_heading level0 col2" >Unidades Vendidas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcce8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fcce8_row0_col0" class="data row0 col0" >Tienda4</td>
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
import pandas as pd

# Calcular promedio ponderado para Tienda
tienda = pd.read_csv(url)
df_tienda = tienda.copy()
numerador_tienda = (df_tienda['Calificación'] * df_tienda['Precio']).sum()
denominador_tienda = df_tienda['Precio'].sum()
promedio_ponderado_tienda = numerador_tienda / denominador_tienda

print(f"Promedio ponderado de calificación para Tienda: {promedio_ponderado_tienda:.4f}")
# Out:
# Promedio ponderado de calificación para Tienda: 4.0133

# %%
import pandas as pd

# Calcular promedio ponderado para Tienda 2
tienda2 = pd.read_csv(url2)
df_tienda2 = tienda2.copy()
numerador_tienda2 = (df_tienda2['Calificación'] * df_tienda2['Precio']).sum()
denominador_tienda2 = df_tienda2['Precio'].sum()
promedio_ponderado_tienda2 = numerador_tienda2 / denominador_tienda2

print(f"Promedio ponderado de calificación para Tienda 2: {promedio_ponderado_tienda2:.4f}")
# Out:
# Promedio ponderado de calificación para Tienda 2: 4.0517

# %%
import pandas as pd

# Calcular promedio ponderado para Tienda 3
tienda3 = pd.read_csv(url3)
df_tienda3 = tienda3.copy()
numerador_tienda3 = (df_tienda3['Calificación'] * df_tienda3['Precio']).sum()
denominador_tienda3 = df_tienda3['Precio'].sum()
promedio_ponderado_tienda3 = numerador_tienda3 / denominador_tienda3

print(f"Promedio ponderado de calificación para Tienda3: {promedio_ponderado_tienda3:.4f}")
# Out:
# Promedio ponderado de calificación para Tienda3: 4.0394

# %%
import pandas as pd

# Calcular promedio ponderado para Tienda 4
tienda4 = pd.read_csv(url4)
df_tienda4 = tienda4.copy()
numerador_tienda4 = (df_tienda4['Calificación'] * df_tienda4['Precio']).sum()
denominador_tienda4 = df_tienda4['Precio'].sum()
promedio_ponderado_tienda4 = numerador_tienda4 / denominador_tienda4

print(f"Promedio ponderado de calificación para Tienda4: {promedio_ponderado_tienda4:.4f}")
# Out:
# Promedio ponderado de calificación para Tienda4: 3.9601

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define las URLs de los archivos CSV
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

# Leer los archivos CSV
tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# Concatenar los datos de todas las tiendas
datos = pd.concat([tienda1, tienda2, tienda3, tienda4])

# Asegurarse de que la columna 'calificacion' sea de tipo float
datos['Calificación'] = datos['Calificación'].astype(float).round(2)

# Agrupar por vendedor y calcular la suma de precios y calificación promedio
ventas_por_vendedor = datos.groupby('Vendedor', as_index=False).agg({
    'Precio': 'sum',  # Asegúrate de que la columna se llame 'Precio'
    'Calificación': 'mean'  # Asegúrate de que la columna se llame 'Calificación'
})

# Renombrar las columnas
ventas_por_vendedor.rename(columns={
    'Precio': 'Suma de Precios',
    'Calificación': 'Calificación Promedio'
}, inplace=True)

# Redondear la columna 'Calificación Promedio' a 2 decimales
ventas_por_vendedor['Calificación Promedio'] = ventas_por_vendedor['Calificación Promedio'].round(2)

# Ordenar de mayor a menor por la suma de precios
ventas_por_vendedor = ventas_por_vendedor.sort_values(by='Suma de Precios', ascending=False)

# Mostrar el DataFrame
print(ventas_por_vendedor)

# Crear un gráfico de barras con dos colores
fig, ax1 = plt.subplots(figsize=(12, 6))

# Gráfico de barras para la suma de precios
ax1.bar(ventas_por_vendedor['Vendedor'], ventas_por_vendedor['Suma de Precios'], color='skyblue', label='Suma de Precios')
ax1.set_ylabel('Suma de Precios', fontsize=12)
ax1.set_xlabel('Vendedor', fontsize=12)
ax1.tick_params(axis='x', rotation=45)
ax1.legend(loc='lower left')

# Crear un segundo eje Y para las calificaciones promedio
ax2 = ax1.twinx()
ax2.plot(ventas_por_vendedor['Vendedor'], ventas_por_vendedor['Calificación Promedio'], color='orange', marker='o', label='Calificación Promedio')
ax2.set_ylabel('Calificación Promedio', fontsize=12)
ax2.legend(loc='lower right')

# Título del gráfico
plt.title('Vendedor : Ventas Totales y Calificación Promedior', fontsize=16)

# Ajustar el diseño
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
#    Vendedor          Suma de Precios  Calificación Promedio
# 3     Felipe Santos 353,796,000      4
# 4   Izabela de León 350,342,400      4
# 8     Maria Alfonso 349,694,800      4
# 6     Juliana Costa 338,364,700      4
# 10      Pedro Gomez 313,350,900      4
# 11    Rafael Acosta 310,292,300      4
# 5    Juan Fernandez 308,562,100      4
# 7     Lucas Olivera 305,403,600      4
# 2     Camila Rivera 303,184,200      4
# 0   Beatriz Morales 302,695,600      4
# 1    Blanca Ramirez 299,586,600      4
# 12   Santiago Silva 293,418,200      4
# 13  Ángel Rodriguez 291,625,200      4
# 9   Mariana Herrera 283,302,600      4

# %%
import pandas as pd

# URLs de los archivos CSV
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

# Diccionario con las URLs de las tiendas
tiendas = {
    'Tienda 1': url,
    'Tienda 2': url2,
    'Tienda 3': url3,
    'Tienda 4': url4
}

# Función para encontrar los 3 productos más y menos vendidos por tienda
def productos_mas_y_menos_vendidos_por_tienda(tiendas):
    resultados = []

    for nombre_tienda, url in tiendas.items():
        # Leer datos de la tienda
        df = pd.read_csv(url)

        # Contar transacciones por producto
        ventas_por_producto = df['Producto'].value_counts().reset_index()
        ventas_por_producto.columns = ['Producto', 'Total Ventas']

        # Obtener los 3 productos con más ventas
        productos_top = ventas_por_producto.head(3)

        # Obtener los 3 productos con menos ventas
        productos_bottom = ventas_por_producto.tail(3)

        # Agregar resultados al DataFrame
        for i in range(3):  # Iterar sobre los 3 productos más y menos vendidos
            resultados.append({
                'Tienda': nombre_tienda,
                'Producto Más Vendido': productos_top.iloc[i]['Producto'] if i < len(productos_top) else None,
                'Total Ventas (Más Vendido)': productos_top.iloc[i]['Total Ventas'] if i < len(productos_top) else None,
                'Producto Menos Vendido': productos_bottom.iloc[i]['Producto'] if i < len(productos_bottom) else None,
                'Total Ventas (Menos Vendido)': productos_bottom.iloc[i]['Total Ventas'] if i < len(productos_bottom) else None
            })

    return pd.DataFrame(resultados)

# Obtener y mostrar resultados
resultado_final = productos_mas_y_menos_vendidos_por_tienda(tiendas)

# Formatear la salida para mejor visualización
resultado_final = resultado_final[['Tienda', 'Producto Más Vendido','Total Ventas (Más Vendido)', 'Producto Menos Vendido',  'Total Ventas (Menos Vendido)']]

# Formatear las columnas numéricas para mostrar separador de miles:
resultado_final['Total Ventas (Más Vendido)'] = resultado_final['Total Ventas (Más Vendido)'].map('{:,.0f}'.format)
resultado_final['Total Ventas (Menos Vendido)'] = resultado_final['Total Ventas (Menos Vendido)'].map('{:,.0f}'.format)

# Aplicar estilo para centrar columnas
styled_df = resultado_final.style.set_properties(**{'text-align': 'center'})



# Mostrar el DataFrame con estilo
styled_df .set_caption('Productos Más y Menos Vendidos por Tienda')
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
import pandas as pd
import numpy as np

# Define las URLs de los archivos CSV
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

# Leer los archivos CSV
tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# Función para calcular el promedio de envíos por tienda
def calcular_envio_promedio(df, nombre_tienda):
    promedio_envio = df['Costo de envío'].mean()  # Asumiendo que la columna de envíos se llama 'Costo de envío'
    return {
        'Tienda': nombre_tienda,
        'Promedio de envío': promedio_envio
    }

# Calcular para cada tienda
resultados_envios = [
    calcular_envio_promedio(tienda, 'Tienda 1'),
    calcular_envio_promedio(tienda2, 'Tienda 2'),
    calcular_envio_promedio(tienda3, 'Tienda 3'),
    calcular_envio_promedio(tienda4, 'Tienda 4')
]

# Crear un DataFrame con los resultados de envíos
df_envios = pd.DataFrame(resultados_envios)
df_envios = df_envios.round(4)

# Aplicar estilos
df_envios_styled = df_envios.style.set_properties(
    **{'text-align': 'left'}, subset=['Tienda']
).set_properties(
    **{'text-align': 'right'}, subset=['Promedio de envío']
)

# Mostrar el DataFrame con estilos
df_envios_styled

# Mostrar el DataFrame sin índice
#df_envios.to_string(index=False)
# Out:
# <style type="text/css">
# #T_db806_row0_col0, #T_db806_row1_col0, #T_db806_row2_col0, #T_db806_row3_col0 {
#   text-align: left;
# }
# #T_db806_row0_col1, #T_db806_row1_col1, #T_db806_row2_col1, #T_db806_row3_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_db806" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db806_level0_col0" class="col_heading level0 col0" >Tienda</th>
#       <th id="T_db806_level0_col1" class="col_heading level0 col1" >Promedio de envío</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db806_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db806_row0_col0" class="data row0 col0" >Tienda 1</td>
#       <td id="T_db806_row0_col1" class="data row0 col1" >26018.609600</td>
#     </tr>
#     <tr>
#       <th id="T_db806_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_db806_row1_col0" class="data row1 col0" >Tienda 2</td>
# ...

# %% [markdown]
# # VENDEDOR : Ventas Totales y Calificación

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define las URLs de los archivos CSV
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

# Leer los archivos CSV
tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# Concatenar los datos de todas las tiendas
datos = pd.concat([tienda1, tienda2, tienda3, tienda4])

# Asegurarse de que la columna 'calificacion' sea de tipo float
datos['Calificación'] = datos['Calificación'].astype(float).round(2)

# Agrupar por vendedor y calcular la suma de precios y calificación promedio
ventas_por_vendedor = datos.groupby('Vendedor', as_index=False).agg({
    'Precio': 'sum',  # Asegúrate de que la columna se llame 'Precio'
    'Calificación': 'mean'  # Asegúrate de que la columna se llame 'Calificación'
})

# Renombrar las columnas
ventas_por_vendedor.rename(columns={
    'Precio': 'Suma de Precios',
    'Calificación': 'Calificación Promedio'
}, inplace=True)

# Redondear la columna 'Calificación Promedio' a 2 decimales
ventas_por_vendedor['Calificación Promedio'] = ventas_por_vendedor['Calificación Promedio'].round(2)

# Ordenar de mayor a menor por la suma de precios
ventas_por_vendedor = ventas_por_vendedor.sort_values(by='Suma de Precios', ascending=False)

# Mostrar el DataFrame
print(ventas_por_vendedor)

# Crear un gráfico de barras con dos colores
fig, ax1 = plt.subplots(figsize=(12, 6))

# Gráfico de barras para la suma de precios
ax1.bar(ventas_por_vendedor['Vendedor'], ventas_por_vendedor['Suma de Precios'], color='skyblue', label='Suma de Precios')
ax1.set_ylabel('Suma de Precios', fontsize=12)
ax1.set_xlabel('Vendedor', fontsize=12)
ax1.tick_params(axis='x', rotation=45)
ax1.legend(loc='lower left')

# Crear un segundo eje Y para las calificaciones promedio
ax2 = ax1.twinx()
ax2.plot(ventas_por_vendedor['Vendedor'], ventas_por_vendedor['Calificación Promedio'], color='orange', marker='o', label='Calificación Promedio')
ax2.set_ylabel('Calificación Promedio', fontsize=12)
ax2.legend(loc='lower right')

# Título del gráfico
plt.title('Vendedor : Ventas Totales y Calificación Promedior', fontsize=16)

# Ajustar el diseño
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
#    Vendedor          Suma de Precios  Calificación Promedio
# 3     Felipe Santos 353,796,000.00   4.08
# 4   Izabela de León 350,342,400.00   3.86
# 8     Maria Alfonso 349,694,800.00   3.96
# 6     Juliana Costa 338,364,700.00   3.92
# 10      Pedro Gomez 313,350,900.00   4.04
# 11    Rafael Acosta 310,292,300.00   4.06
# 5    Juan Fernandez 308,562,100.00   4.03
# 7     Lucas Olivera 305,403,600.00   3.96
# 2     Camila Rivera 303,184,200.00   4.03
# 0   Beatriz Morales 302,695,600.00   4.05
# 1    Blanca Ramirez 299,586,600.00   3.99
# 12   Santiago Silva 293,418,200.00   4.03
# 13  Ángel Rodriguez 291,625,200.00   4.13
# 9   Mariana Herrera 283,302,600.00   4.07

# %% [markdown]
# #Ventas Totales por Vendedor

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define las URLs de los archivos CSV
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

# Leer los archivos CSV
tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# Agregar una columna para identificar la tienda
tienda1["Tienda"] = "Tienda 1"
tienda2["Tienda"] = "Tienda 2"
tienda3["Tienda"] = "Tienda 3"
tienda4["Tienda"] = "Tienda 4"

# Concatenar los datos de todas las tiendas
datos = pd.concat([tienda1, tienda2, tienda3, tienda4])

# Agrupar por vendedor y calcular la suma de precios
ventas_por_vendedor = datos.groupby('Vendedor', as_index=False).agg({'Precio': 'sum'})

# Renombrar las columnas
ventas_por_vendedor.rename(columns={
    'Precio': 'Venta Total',
    'Calificación': 'Calificación Promedio'
}, inplace=True)

# Ordenar de mayor a menor por la suma de precios
ventas_por_vendedor = ventas_por_vendedor.sort_values(by='Venta Total', ascending=False)

# Mostrar el DataFrame
print(ventas_por_vendedor)

# Crear un gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(ventas_por_vendedor['Vendedor'], ventas_por_vendedor['Venta Total'], color='skyblue')
plt.title('Suma de Precios por Vendedor', fontsize=16)
plt.xlabel('Vendedor', fontsize=12)
plt.ylabel('Suma de Precios', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
#    Vendedor          Venta Total
# 3     Felipe Santos 353,796,000.00
# 4   Izabela de León 350,342,400.00
# 8     Maria Alfonso 349,694,800.00
# 6     Juliana Costa 338,364,700.00
# 10      Pedro Gomez 313,350,900.00
# 11    Rafael Acosta 310,292,300.00
# 5    Juan Fernandez 308,562,100.00
# 7     Lucas Olivera 305,403,600.00
# 2     Camila Rivera 303,184,200.00
# 0   Beatriz Morales 302,695,600.00
# 1    Blanca Ramirez 299,586,600.00
# 12   Santiago Silva 293,418,200.00
# 13  Ángel Rodriguez 291,625,200.00
# 9   Mariana Herrera 283,302,600.00

# %% [markdown]
# # CONSUMOS DE PRODUCTOS

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define las URLs de los archivos CSV
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

# Leer los archivos CSV
tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# Agregar una columna para identificar la tienda
tienda1["Tienda"] = "Tienda 1"
tienda2["Tienda"] = "Tienda 2"
tienda3["Tienda"] = "Tienda 3"
tienda4["Tienda"] = "Tienda 4"

# Concatenar los datos de todas las tiendas
datos = pd.concat([tienda1, tienda2, tienda3, tienda4])

# %% [markdown]
# # Carga de ventas por dia semana por tienda. Herramienta para determinar distribución de personal

# %%
import pandas as pd

# Define las URLs de los archivos CSV
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

# Leer los archivos CSV
tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# Concatenar los datos de todas las tiendas
datos = pd.concat([tienda1, tienda2, tienda3, tienda4])

# Convertir la columna 'fecha' a tipo datetime (asegúrate de que la columna se llame 'fecha')
datos['Fecha de Compra'] = pd.to_datetime(datos['Fecha de Compra'])

# Crear columnas de Año, Mes y Día de la Semana
datos['Año'] = datos['Fecha de Compra'].dt.year
datos['Mes'] = datos['Fecha de Compra'].dt.month
datos['Día de la Semana'] = datos['Fecha de Compra'].dt.day_name()

# Mapeo de días en inglés a español
dias_ingles_espanol = {
    'Monday': 'Lunes',
    'Tuesday': 'Martes',
    'Wednesday': 'Miércoles',
    'Thursday': 'Jueves',
    'Friday': 'Viernes',
    'Saturday': 'Sábado',
    'Sunday': 'Domingo'
}

# Obtener el nombre del día en inglés y mapearlo a español
datos['Día de la Semana'] = datos['Fecha de Compra'].dt.day_name().map(dias_ingles_espanol)



# Mostrar las primeras filas del DataFrame con las nuevas columnas
print(datos[['Día de la Semana']].head())
#print(datos[['Fecha de Compra', 'Año', 'Mes', 'Día de la Semana']].head())
# Out:
#   Día de la Semana
# 0     Sábado
# 1  Miércoles
# 2      Lunes
# 3     Martes
# 4     Sábado
# <ipython-input-171-a5c0051f6302>:19: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   datos['Fecha de Compra'] = pd.to_datetime(datos['Fecha de Compra'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Configuración para mostrar los días en español
dias_ingles_espanol = {
    'Monday': 'Lunes',
    'Tuesday': 'Martes',
    'Wednesday': 'Miércoles',
    'Thursday': 'Jueves',
    'Friday': 'Viernes',
    'Saturday': 'Sábado',
    'Sunday': 'Domingo'
}

# URLs de los archivos CSV
urls = [
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"
]

# Leer y concatenar los datos
datos = pd.concat([pd.read_csv(url) for url in urls])

# Convertir fecha y extraer información
datos['Fecha de Compra'] = pd.to_datetime(datos['Fecha de Compra'])
datos['Año'] = datos['Fecha de Compra'].dt.year
datos['Día_Semana'] = datos['Fecha de Compra'].dt.day_name().map(dias_ingles_espanol)

# Ordenar los días de la semana correctamente
orden_dias = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']
datos['Día_Semana'] = pd.Categorical(datos['Día_Semana'], categories=orden_dias, ordered=True)

# Agrupar por Año y Día de la Semana
resumen = datos.groupby(['Año', 'Día_Semana']).agg({'Precio': 'sum', 'Calificación': 'mean'}).reset_index()
resumen.columns = ['Año', 'Día de la Semana', 'Suma de Precio', 'Media de Calificación']

# Mostrar el DataFrame resultante
print("Resumen por año y día de la semana:")
print(resumen)

# Crear gráficos
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

# Gráfico de suma de precios por día y año
datos.pivot_table(index='Día_Semana', columns='Año', values='Precio', aggfunc='sum').plot.bar(ax=ax1)
ax1.set_title('Suma de Precios por Día de la Semana (Separado por Año)')
ax1.set_ylabel('Suma de Precios')
ax1.legend(title='Año')

# Gráfico de suma de calificaciones por día y año
datos.pivot_table(index='Día_Semana', columns='Año', values='Calificación', aggfunc='sum').plot.bar(ax=ax2)
ax2.set_title('Media de Calificaciones por Día de la Semana (Separado por Año)')
ax2.set_ylabel('Media de Calificaciones')
ax2.legend(title='Año')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-173-b0afea408b81>:27: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   datos['Fecha de Compra'] = pd.to_datetime(datos['Fecha de Compra'])
# <ipython-input-173-b0afea408b81>:36: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   resumen = datos.groupby(['Año', 'Día_Semana']).agg({'Precio': 'sum', 'Calificación': 'mean'}).reset_index()
# Resumen por año y día de la semana:
#     Año  Día de la Semana  Suma de Precio  Media de Calificación
# 0   2020      Lunes       169,579,900.00  3.86
# 1   2020     Martes       209,828,700.00  3.97
# 2   2020  Miércoles       205,088,100.00  4.12
# 3   2020     Jueves       187,072,000.00  3.98
# ...

# %% [markdown]
# otra

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Configuración para mostrar los días en español
dias_ingles_espanol = {
    'Monday': 'Lunes',
    'Tuesday': 'Martes',
    'Wednesday': 'Miércoles',
    'Thursday': 'Jueves',
    'Friday': 'Viernes',
    'Saturday': 'Sábado',
    'Sunday': 'Domingo'
}

# URLs de los archivos CSV
urls = [
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"
]

# Leer y concatenar los datos
datos = pd.concat([pd.read_csv(url) for url in urls])

# Convertir fecha y extraer información
datos['Fecha de Compra'] = pd.to_datetime(datos['Fecha de Compra'])
datos['Año'] = datos['Fecha de Compra'].dt.year
datos['Día_Semana'] = datos['Fecha de Compra'].dt.day_name().map(dias_ingles_espanol)

# Ordenar los días de la semana correctamente
orden_dias = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']
datos['Día_Semana'] = pd.Categorical(datos['Día_Semana'], categories=orden_dias, ordered=True)

# Agrupar por Año y Día de la Semana
resumen = datos.groupby(['Año', 'Día_Semana']).agg({'Precio': 'sum', 'Calificación': 'mean'}).reset_index()
resumen.columns = ['Año', 'Día de la Semana', 'Suma de Precio', 'Media de Calificación']

# Mostrar el DataFrame resultante
print("Resumen por año y día de la semana:")
print(resumen)

# Crear gráficos
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

# Gráfico de suma de precios por día y año
datos.pivot_table(index='Día_Semana', columns='Año', values='Precio', aggfunc='sum').plot.bar(ax=ax1)
ax1.set_title('Suma de Precios por Día de la Semana (Separado por Año)')
ax1.set_ylabel('Suma de Precios')
ax1.legend(title='Año')

# Gráfico de suma de calificaciones por día y año
datos.pivot_table(index='Día_Semana', columns='Año', values='Calificación', aggfunc='sum').plot.bar(ax=ax2)
ax2.set_title('Media de Calificaciones por Día de la Semana (Separado por Año)')
ax2.set_ylabel('Media de Calificaciones')
ax2.legend(title='Año')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-173-b0afea408b81>:27: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   datos['Fecha de Compra'] = pd.to_datetime(datos['Fecha de Compra'])
# <ipython-input-173-b0afea408b81>:36: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   resumen = datos.groupby(['Año', 'Día_Semana']).agg({'Precio': 'sum', 'Calificación': 'mean'}).reset_index()
# Resumen por año y día de la semana:
#     Año  Día de la Semana  Suma de Precio  Media de Calificación
# 0   2020      Lunes       169,579,900.00  3.86
# 1   2020     Martes       209,828,700.00  3.97
# 2   2020  Miércoles       205,088,100.00  4.12
# 3   2020     Jueves       187,072,000.00  3.98
# ...
